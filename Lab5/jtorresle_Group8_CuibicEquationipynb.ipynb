# %% [markdown]
# <a href="https://colab.research.google.com/github/JorgeAndresTorresLeal/MetNumUN2023II/blob/main/Lab5/jtorresle_Group8_CuibicEquationipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Jorge A. Torres L.
#   * UN ID: jatorres
#   * Last digit C.C: 9
#   * Last digit list number: 5
#   * ![Sin título.png](data:image/png;base64,...)
# * Javier A. Carrillo C.
#   * UN ID: jacarrillo
#   * Last digit C.C: 3
#   * Last digit list number: 8
#   * ![WhatsApp Image 2023-10-11 at 6.51.33 PM.jpeg](data:image/jpeg;base64,...)
# * Javier S. Vargas P.
#   * UN ID: javargaspa
#   * Last digit C.C: 1
#   * Last digit list number: 7
#   * ![image.png](data:image/png;base64,...)

# %% [markdown]
# Modify [week_1_quadratic_Po_Shen_Loh.ipyn](https://colab.research.google.com/drive/15vXGB18_np6o0Rw8ZV4o08RTdCdDIdT0?usp=sharing) for
#
# $$ ax^3+bx^+cx +d = 0$$
#
# using Cubic equation – General cubic formula- [wikipedia](https://en.wikipedia.org/wiki/Cubic_equation)
#
# Asuume $a=1$ then work wequations are of the form
#
# $$ x^3+bx^+cx +d = 0$$
#
# Including plots, expalnations, solution code and test cases

# %% [markdown]
# # Explicación
# La función solve_cubic resuelve una ecuación cúbica de la forma $x^3 + bx^2 + cx + d = 0$ por medio de la fórmula cúbica general explicada en el wikipedia de arriba, sin embargo, aquí mostraremos cómo pasamos ésta explicación a un algoritmo.
# Primero los coeficientes $b,c$ y $d$ provenientes de la cúbica a resolver se pasan como argumentos a la función.
#
# Posteriormente se calculan p y q que en wikipedia son nombrados como Δ1 y Δ2 los cuales se calculan como $Δ1 = b^2 -3*a*c $ y $Δ2 = 2*b^3 - 9*a*b*c + 27*a^2*d$.
#
# Luego calculamos C1 y C2 que se usrán posteriormente, al igual que l.
#
# Luego procedemos a comprobar si p y q son igual a cero pues de ser ese el caso el método en wikipedia nos indica que el resultado de las tres raíces es $\frac{-b}{3}$.
#
# De no darse el caso anterior debemos proceder a usar el resultado de C1 o C2 pues en sí mismas son la misma fórmula solo que con una diferencia de signo entre ellas, el porqué esta elección es algo arbitrario se debe a que como se explica en wikipedia cuando el resultado de una da 0 debemos simplemente usar el otro C que tiene el signo contrario,por ello la elección de comprobar qué C da igual a cero es totalmente arbitrario, y en este caso elegimos verificar si C1(fórmula con signo positivo) es 0.

# %%
import numpy as np
import matplotlib.pyplot as plt
def cubic(b,c,d,x):
    """Calulate the value of the  qubic equation, v = x**3 + bx**2 + c*x +d
    Parameters
    ----------
    b, c, d  : float
       Coefficients

    Returns
    -------
    v : float """

    # ... enter your code here ...
    v = x**3+b*x**2+c*x+d
    return v

x = np.arange(-3.5, 2, 0.001)
z = np.zeros(len(x))
y = cubic(2,3,-2,x)

# %%
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='$Ecuación Cúbica: x^3 + 2x^2 + 3x - 2$')
plt.plot(x, z, 'r--', label='$y = 0$')  # Línea horizontal y=0 en rojo punteada
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfica de una Ecuación Cúbica')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# %%
import cmath

def solve_cubic(b, c,d):
    """Solve a cubic equation, x**3 + bx**2 + c*x +d = 0.

    Parameters
    ----------
    b, c,d : float
       Coefficients

    Returns
    -------
    x1, x2,x3 : float or complex
       Roots.  """

    # ... enter your code here ...
    p = b**2-3*c
    q = 2*b**3-9*b*c+27*d
    C1 = ((q + cmath.sqrt(q**2 - 4*p**3))/2)**(1/3)
    C2 = ((q - cmath.sqrt(q**2 - 4*p**3))/2)**(1/3)
    l = (-1 + cmath.sqrt(-3))/2
    if p == 0 and q == 0:
      x1 = -b/3
      x2 = -b/3
      x3 = -b/3
    elif C1 == 0:
      x1 = -(1/3) * (b + l**0*C2 + p/(l**0*C2))
      x2 = -(1/3) * (b + l**1*C2 + p/(l**1*C2))
      x3 = -(1/3) * (b + l**2*C2 + p/(l**2*C2))
    else:
      x1 = -(1/3) * (b + l**0*C1 + p/(l**0*C1))
      x2 = -(1/3) * (b + l**1*C1 + p/(l**1*C1))
      x3 = -(1/3) * (b + l**2*C1 + p/(l**2*C1))

    return x1,x2,x3

# %% [markdown]
# Bulit test cases that include
#
# $$(x-1) \left( x + \frac{1}{2} + i \frac{\sqrt{3}}{2}\right) \left( x + \frac{1}{2} - i \frac{\sqrt{3}}{2}\right) =   x^3 -1 =  0  $$
#
# $$(x-1)^3 = x^3 - 3 x^2 + 3 x - 1 = 0 $$
#
# $$(x-1)(x-i)(x+i) = x^3 - x^2 + x - 1 = 0 $$
#
# $$ (x+2)^2 (x-1) = x^3 + 3 x^2 - 4 = 0  $$
#
# $$(x+3)(x+1)(x+9) = x^3 + 13 x^2 + 39 x + 27  = 0 $$
#
# $$(x+2)(x+4)(x+8) = x^3 + 12 x^2 + 56 x + 64  = 0 $$
#
# $$(x+20+50000i)(x+50-3i)(x+6+1i) = x^3 + (76 + 498 i) x^2 + (2423 + 27992 i) x - (9940 - 152140 i)  = 0 $$
#
# $$(x+0.4+500i)(x+50-3i)(x+6+1i) = (56.4 + 498 i) x^2 + (1325.4 + 28031.2 i) x - (15878.8 - 151513. i) + x^3  = 0 $$
#
#
# three real diferent roots,  roots in the last digits of the group members, root of mtiuplicity two, and complex roots with small and large $b$.
#
# **Last digits:** Javier Carrilo (3), Jorge Torres (9), Javier Vargas (1)

# %%
from numpy import allclose

variants = [{'b': 0.0, 'c': 0.0, 'd': -1.0},
            {'b': -3.0, 'c': 3.0, 'd':-1.0},
            {'b': -1.0, 'c': 1.0, 'd':-1.0},
            {'b':  3.0, 'c': 0.0, 'd':-4.0},
            {'b':  3.0, 'c': 9.0, 'd': 1.0}, #roots in the last digits
            {'b':  2.0, 'c': 4.0, 'd': 8.0}, #roots in multiplicity two
            {'b':  20.0 + 50000j, 'c': 50-3j, 'd': 6+1j}, #complex roots with large b
            {'b':  0.4 + 500j, 'c': 50-3j, 'd': 6+1j}, #complex roots with small b
            ]

for var in variants:
    x1, x2, x3= solve_cubic(**var)
    print(allclose(cubic(var['b'],var['c'],var['d'],x1), 0.0) and allclose(cubic(var['b'],var['c'],var['d'],x2), 0.0) and  allclose(cubic(var['b'],var['c'],var['d'],x3), 0.0))
# Out:
# True
# True
# True
# True
# True
# True
# False
# True

# %%
import cmath

def solve_cubic_with_large_b(b, c,d):
    """Solve a cubic equation, x**3 + bx**2 + c*x +d = 0.

    Parameters
    ----------
    b, c,d : float
       Coefficients

    Returns
    -------
    x1, x2,x3 : float or complex
       Roots.  """

    # ... enter your code here ...
    p = b**2-3*c
    q = 2*b**3-9*b*c+27*d
    C1 = ((q + cmath.sqrt(q**2 - 4*p**3))/2)**(1/3)
    C2 = ((q - cmath.sqrt(q**2 - 4*p**3))/2)**(1/3)
    l = (-1 + cmath.sqrt(-3))/2


    if b > 1e4:
      if c == 0 and d == 0:
        x1 = 0
        x2 = 0
        x3 = -b
      elif d == 0:
        x1 = 0
        x2 = -b
        x3 = -c/b
      else:
        if allclose(cubic(b,c,d,np.roots([1, b, c, d])[0]),0.0):
          z = np.roots([1, b, c, d])[0]
          x1 = z
          x2 = -(b+z)
          x3 = (z**2 + b*z)/d
        elif allclose(cubic(b,c,d,np.roots([1, b, c, d])[1]),0.0):
          z = np.roots([1, b, c, d])[1]
          x1 = z
          x2 = -(b+z)
          x3 = (z**2 + b*z)/d
        else:
          z = np.roots([1, b, c, d])[2]
          x1 = z
          x2 = -(b+z)
          x3 = (z**2 + b*z)/d
       # Se calculan las otras dos raíces usando la fórmula
          x1 = z
          x2 = -(b+z)
          x3 = (z**2 + b*z)/d
    else:
      if p == 0 and q == 0:
        x1 = -b/3
        x2 = -b/3
        x3 = -b/3
      elif C1 == 0:
        x1 = -(1/3) * (b + l**0*C2 + p/(l**0*C2)) ## + (p/C2*l**0)
        x2 = -(1/3) * (b + l**1*C2 + p/(l**1*C2)) ## + (p/C2*l**1)
        x3 = -(1/3) * (b + l**2*C2 + p/(l**2*C2)) ## + (p/C2*l**2)
      else:
        x1 = -(1/3) * (b + l**0*C1 + p/(l**0*C1)) ## + (p/C1*l**0)
        x2 = -(1/3) * (b + l**1*C1 + p/(l**1*C1)) ## + (p/C1*l**1)
        x3 = -(1/3) * (b + l**2*C1 + p/(l**2*C1)) ## + (p/C1*l**2)

    return x1,x2,x3

# %%
from numpy import allclose

variants = [{'b': 0.0, 'c': 0.0, 'd': -1.0},
            {'b': -3.0, 'c': 3.0, 'd':-1.0},
            {'b': -1.0, 'c': 1.0, 'd':-1.0},
            {'b':  3.0, 'c': 0.0, 'd':-4.0},
            {'b':  1e6, 'c': 0.0,  'd':0.0},
            {'b':  1e7, 'c': 0.0,  'd':0.0},
            {'b':  1e6, 'c': 1.0,  'd':0.0},
            {'b':  1e7, 'c': 1.0,  'd':0.0},
            {'b':  1e6, 'c': -1.0,  'd':0.0},
            {'b':  1e7, 'c': -1.0,  'd':0.0},
            {'b':  -1e6, 'c': 1.0,  'd':0.0},
            {'b':  -1e7, 'c': 1.0,  'd':0.0},
            {'b':  -1e6, 'c': -1.0,  'd':0.0},
            {'b':  -1e7, 'c': -1.0,  'd':0.0},
            {'b':  1e6, 'c': 1.0,  'd':1.0},
            {'b':  1e6, 'c': 1.0,  'd':-1.0},
            {'b':  1e6, 'c': -1.0,  'd':1.0},
            {'b':  1e6, 'c': -1.0,  'd':-1.0},
            {'b':  1e7, 'c': 1.0,  'd':1.0},
            {'b':  1e7, 'c': 1.0,  'd':-1.0},
            {'b':  1e7, 'c': -1.0,  'd':1.0},
            {'b':  1e7, 'c': -1.0,  'd':-1.0},
            {'b':  1e8, 'c': 1.0,  'd':1.0},
            {'b':  1e8, 'c': 1.0,  'd':-1.0},
            {'b':  1e8, 'c': -1.0,  'd':1.0}#,
            # {'b':  1e8, 'c': -1.0,  'd':-1.0},
            # {'b':  3.0, 'c': 9.0, 'd': 1.0}, #roots in the last digits
            # {'b':  2.0, 'c': 4.0, 'd': 8.0}, #roots in multiplicity two
            # {'b':  20.0 + 50000j, 'c': 50-3j, 'd': 6+1j}, #complex roots with large b
            # {'b':  0.4 + 500j, 'c': 50-3j, 'd': 6+1j}, #complex roots with small b
            ]

for var in variants:
    x1, x2, x3= solve_cubic_with_large_b(**var)
    print(allclose(cubic(var['b'],var['c'],var['d'],x1), 0.0) and allclose(cubic(var['b'],var['c'],var['d'],x2), 0.0) and  allclose(cubic(var['b'],var['c'],var['d'],x3), 0.0))
    # print('root1',allclose(cubic(var['b'],var['c'],var['d'],x1), 0.0))
    # print('root2',allclose(cubic(var['b'],var['c'],var['d'],x2), 0.0))
    # print('root3',allclose(cubic(var['b'],var['c'],var['d'],x3), 0.0))
# Out:
# True
# True
# True
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
def graficador(b, c, d):
  x = np.arange(-3.5, 2, 0.001)
  z = np.zeros(len(x))
  y = cubic(b,c,d,x)

  plt.figure(figsize=(8, 6))
  plt.plot(x, y, label= f'$Ecuación Cúbica: x^3 + {b}x^2 + {c}x - {d}')
  plt.plot(x, z, 'r--', label='$y = 0$')  # Línea horizontal y=0 en rojo punteada
  plt.xlabel('x')
  plt.ylabel('y')
  plt.title('Gráfica de una Ecuación Cúbica')
  plt.axhline(0, color='black', linewidth=0.5)
  plt.axvline(0, color='black', linewidth=0.5)
  plt.grid(color='gray', linestyle='--', linewidth=0.5)
  plt.legend()
  plt.show()

for var in variants:
  graficador(var['b'], var['c'], var['d'])

# %% [markdown]
#  Publish the notebook in as **pperezp_groupN_CubicEquation.ipynb** at **MetNumUN2023II/Lab5** and submit only the code of **solve_cubic(b, c,d)** in UNcode Quiz Cubic Equation.
